# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sbn

# %%
data = pd.read_csv("../data/trial_output05.tsv", sep='\t', header=None)
data = data.drop(columns=[0, 1])
data = data.groupby([2,3]).mean()
display(data)
data_to_plot = data[6].reset_index().pivot(columns=2, index=3)
sbn.heatmap(data_to_plot)
data
# Out:
#                     4       5         6         7         8         9   \
# 2     3
# 9.215 33.340  9.215036  33.340 -0.009157 -0.001375 -0.004885  0.001171
#       33.343  9.215033  33.343 -0.002789  0.003701 -0.005765 -0.008689
#       33.346  9.215025  33.346 -0.005283 -0.003084 -0.005658 -0.007267
#       33.349  9.215008  33.349 -0.010137 -0.013489 -0.005900 -0.002226
#       33.352  9.215050  33.352 -0.007884 -0.021374 -0.007079 -0.006731
# ...                ...     ...       ...       ...       ...       ...
# 9.413 33.499  9.413000  33.499 -0.007026  0.000295 -0.005256 -0.004773
#       33.502  9.413000  33.502 -0.004973 -0.010444 -0.006026 -0.011468
#       33.505  9.413000  33.505 -0.008338 -0.001989 -0.002428  0.001873
#       33.508  9.412992  33.508 -0.005685 -0.011853 -0.007267 -0.005792
#       33.511  9.413000  33.511 -0.010766 -0.013750 -0.004944  0.000790
#
#                     10        11        12        13
# 2     3
# ...

# %%
data_to_plot
# Out:
#              4                                                              \
# 2        9.213     9.214     9.215     9.216     9.217     9.218     9.219
# 3
# 33.340     NaN -0.005667 -0.006900       NaN -0.003864 -0.004722 -0.002667
# 33.343     NaN -0.006000 -0.005882       NaN -0.004179 -0.004966 -0.006667
# 33.346     NaN -0.005464 -0.005667  0.008000 -0.007750 -0.005703 -0.005000
# 33.349     NaN -0.006421 -0.005415 -0.004000 -0.004917 -0.007083 -0.005000
# 33.352 -0.0060 -0.007000 -0.007486 -0.004500 -0.004810 -0.006432 -0.004333
# 33.355     NaN -0.006864 -0.005711 -0.005000 -0.004474 -0.006795 -0.006333
# 33.358 -0.0080 -0.007913 -0.004974 -0.013000 -0.006105 -0.004711 -0.002800
# 33.361     NaN -0.005893 -0.003882 -0.009000 -0.005412 -0.006125 -0.010000
# 33.364     NaN -0.005071 -0.005758 -0.012000 -0.008444 -0.006462 -0.003500
# 33.367     NaN -0.004091 -0.007886 -0.007750 -0.007429 -0.007216 -0.002000
# ...
